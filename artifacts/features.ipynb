# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

# %%
anime = pd.read_csv('./anime_dataset_1/anime.csv')
anime_with_synopsis = pd.read_csv('./anime_dataset_1/anime_with_synopsis.csv')

train_set = pd.read_parquet('./data/train.parquet')
test_set = pd.read_parquet('./data/test.parquet')

# %% [markdown]
# ## Признаки пользователей

# %%
data = train_set.reset_index(drop=True)

# %%
data.columns
# Out:
# Index(['user_id', 'anime_id', 'rating', 'watching_status', 'watched_episodes'], dtype='object')

# %%
data = data.merge(anime, left_on='anime_id', right_on='MAL_ID', how='left')

# %%
user_ids = data['user_id'].unique().tolist()
item_ids = data['anime_id'].unique().tolist()

# %%
data['user_idx'] = pd.Categorical(data['user_id']).codes
data['item_idx'] = pd.Categorical(data['anime_id']).codes

# %%
len(user_ids), len(item_ids)
# Out:
# (29214, 15695)

# %%
user_idx = data['user_idx'].to_numpy().flatten()
item_idx = data['item_idx'].to_numpy().flatten()

rating = data['rating'].to_numpy().flatten()

# %%
sparse_matrix = csr_matrix(
    (rating, (user_idx, item_idx)),
    shape=(len(user_ids), len(item_ids))
)

# %%
similarity_matrix = cosine_similarity(sparse_matrix)

# %%
similarity_matrix.shape
# Out:
# (29214, 29214)

# %%
def recommend(user_id, top_k=10):
    user_idx = user_ids.index(user_id)
    scores = similarity_matrix[user_idx] @ sparse_matrix
    recommended_indices = np.argsort(scores)[::-1][:top_k]
    recommended_item_ids = [item_ids[i] for i in recommended_indices]

    return recommended_item_ids

# %%
# Out:
#        MAL_ID                             Name    Score  \
# 58         79                         Shuffle!     7.09
# 2218     2421                   Super Kuma-san     6.13
# 3285     3799                            Speed     5.18
# 3928     5031  Cobra The Animation: Time Drive     6.92
# 7473    16586     Michitekuru Toki no Mukou ni  Unknown
# 9368    25641             Monotonous Purgatory     6.18
# 9437    26035                       Sweet Spot  Unknown
# 11823   33281                    Mori no Andou     5.92
# 13841   36754            Kakuriyo no Yadomeshi      7.5
# 17334   44059                          Puparia     7.48
#
#                                                   Genres  \
# 58     Harem, Comedy, Drama, Magic, Romance, Ecchi, F...
# 2218                                     Comedy, Fantasy
# 3285                                              Comedy
# 3928                    Action, Adventure, Space, Sci-Fi
# 7473                         Adventure, Fantasy, Romance
# 9368                                               Music
# 9437                                              Comedy
# 11823                                             Comedy
# 13841               Demons, Drama, Romance, Supernatural
# 17334                                           Dementia
#
#                                  English name                 Japanese name  \
# 58                                   Shuffle!             SHUFFLE! (シャッフル!)
# 2218                                  Unknown                      スーパークマさん
# 3285                                  Unknown                          スピード
# 3928                                  Unknown  COBRA THE ANIMATION タイム・ドライブ
# 7473                                  Unknown                  満ちてくる　時のむこうに
# 9368                                  Unknown          MONOTONOUS PURGATORY
# 9437                                  Unknown                      スイートスポット
# 11823                                 Unknown                          森の安藤
# 13841  Kakuriyo:Bed and Breakfast for Spirits                       かくりよの宿飯
# 17334                                 Puparia                       PUPARIA
#
#           Type Episodes                         Aired    Premiered  ...  \
# 58          TV       24    Jul 8, 2005 to Jan 6, 2006  Summer 2005  ...
# 2218   Special        1                   Jun 1, 2003      Unknown  ...
# 3285     Movie        1                   Jan 1, 1980      Unknown  ...
# 3928       OVA        2  Apr 24, 2009 to Jun 26, 2009      Unknown  ...
# 7473   Special        1                  Jun 16, 1991      Unknown  ...
# 9368     Music        1                  Oct 26, 2012      Unknown  ...
# 9437       OVA        1                  Apr 21, 1991      Unknown  ...
# 11823      ONA        1                     Jan, 2006      Unknown  ...
# 13841       TV       26   Apr 2, 2018 to Sep 24, 2018  Spring 2018  ...
# 17334      ONA        1                  Nov 20, 2020      Unknown  ...
#
#       Score-10  Score-9  Score-8  Score-7  Score-6  Score-5 Score-4  Score-3  \
# 58      8852.0  14660.0  26443.0  32343.0  18951.0  10530.0  5019.0   2184.0
# 2218      15.0     17.0     33.0     67.0     93.0     64.0    22.0     10.0
# 3285       5.0      9.0     24.0     70.0     98.0    120.0    74.0     43.0
# 3928      82.0    128.0    357.0    532.0    298.0    133.0    45.0     17.0
# 7473       5.0      6.0      4.0      9.0      9.0      6.0     2.0      2.0
# 9368      20.0     32.0     95.0    169.0    175.0    125.0    48.0     12.0
# 9437       6.0      2.0      4.0     16.0     23.0     25.0    12.0      5.0
# 11823    274.0     67.0    114.0    170.0    201.0    148.0   104.0    103.0
# 13841   3539.0   5112.0   9551.0  10033.0   4754.0   2368.0   872.0    311.0
# 17334    490.0    615.0   1092.0   1036.0    517.0    238.0    71.0     39.0
#
#        Score-2  Score-1
# 58      1323.0   1088.0
# 2218       9.0      5.0
# 3285      31.0     35.0
# 3928       9.0     12.0
# 7473       1.0      2.0
# 9368      11.0     21.0
# 9437       3.0      3.0
# 11823    104.0    144.0
# 13841    138.0    109.0
# 17334     18.0     19.0
#
# [10 rows x 35 columns]

# %%
user_interactions_count = data.groupby('user_id').size()

# %%
user_avg_rating = data.groupby('user_id')['rating'].mean()

# %%
user_genres = data.groupby('user_id')['Genres'].apply(lambda x: ','.join(set(','.join(x).split(','))))

# %%
user_episodes_watched = data.groupby('user_id')['watched_episodes'].sum()
